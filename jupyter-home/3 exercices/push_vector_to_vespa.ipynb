# %%
# !pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd

# %%
from sentence_transformers import SentenceTransformer
# 1. Load a pretrained Sentence Transformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# The sentences to encode
sentences = [
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
]

# 2. Calculate embeddings by calling model.encode()
embeddings = model.encode(sentences)
print(embeddings.shape)
# [3, 384]

# 3. Calculate the embedding similarities
similarities = model.similarity(embeddings, embeddings)
print(similarities)
# tensor([[1.0000, 0.6660, 0.1046],
#         [0.6660, 1.0000, 0.1411],
#         [0.1046, 0.1411, 1.0000]])
# Out:
# (3, 384)
# tensor([[1.0000, 0.6660, 0.1046],
#         [0.6660, 1.0000, 0.1411],
#         [0.1046, 0.1411, 1.0000]])

# %%
id:beer:beer::beer:4134

# %%
def craft_id_and_vector(s: pd.Series):
    return {}

# %%
df = pd.read_csv("/data/beers_full.csv")

# %%
def craft_description(s: pd.Series) -> str:
    description_el = [
        s.name if s.name is not None else "",
        s.description_beer if s.description_beer is not None else "",
        s.description_brewery if s.description_brewery is not None else "",
    ]
    return ". ".join(description_el)
descriptions = df.apply(craft_description, axis=1).to_list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       2     description_el = [
#       3         s.name if s.name is not None else "",
#       4         s.description_beer if s.description_beer is not None else "",
#       5         s.description_brewery if s.description_brewery is not None else "",
#       6     ]
#       7     return ". ".join(description_el)
# ----> 8 descriptions = df.apply(craft_description, axis=1).to_list()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
descriptions
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
df.apply(craft_id_and_vector, axis=1)
# Out:
#         id  brewery_id                    name  cat_id  style_id  abv  ibu  \
# 0        1         812             Hocus Pocus      11       116  4.5  0.0
# 1        2         264       Grimbergen Blonde      -1        -1  6.7  0.0
# 2        3         779  Widdershins Barleywine      -1        -1  9.1  0.0
# 3        4         287                 Lucifer      -1        -1  8.5  0.0
# 4        5        1056                  Bitter      -1        -1  4.0  0.0
# ...    ...         ...                     ...     ...       ...  ...  ...
# 5951  5910          10           Honey Rye Ale      11       128  0.0  0.0
# 5952  5911          10              Strawberry      11       121  0.0  0.0
# 5953  5912          10             Satsuma Wit      11       121  0.0  0.0
# 5954  5913        1422               Abhi beer       7        89  0.0  0.0
# 5955  5914        1423                    Ambr      11       132  0.0  0.0
#
# ...
